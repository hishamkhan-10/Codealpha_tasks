# %% [markdown]
# **Step 1: Install Required Tools**

# %%
# !pip install streamlit pyngrok --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 377.9 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 2.7 MB/s eta 0:00:00

# %% [markdown]
# **Step 2: Write Your Streamlit Code into a Python File**

# %%
# %%writefile app.py
import streamlit as st
import numpy as np
import tensorflow as tf
import pickle
from PIL import Image

model = tf.keras.models.load_model('age_group_classifier.h5')
with open('label_encoder.pkl', 'rb') as f:
    le = pickle.load(f)

st.title("Age Group Prediction from Face Image")
st.write("Upload a face image to predict the person's age group.")

uploaded_file = st.file_uploader("Choose an image...", type=["jpg", "jpeg", "png"])

if uploaded_file:
    img = Image.open(uploaded_file)
    st.image(img, caption="Uploaded Image", use_column_width=True)

    img = img.resize((128, 128))
    img_array = np.array(img) / 255.0
    if img_array.shape[-1] == 4:
        img_array = img_array[..., :3]

    img_array = img_array.reshape(1, 128, 128, 3)
    prediction = model.predict(img_array)
    class_index = np.argmax(prediction)
    class_label = le.classes_[class_index]

    st.success(f"Predicted Age Group: **{class_label}**")
# Out:
# Overwriting app.py

# %% [markdown]
# **Step 3: Upload Your Model Files**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-22ae7b8d-7870-417b-a6cc-4a3aa67247ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-22ae7b8d-7870-417b-a6cc-4a3aa67247ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Step 4: Authenticate ngrok in Google Colab**

# %%
# !ngrok config add-authtoken 2xlzmts0jlWfapjWtPc3xG720Rl_3XvYUTBgGKwu11b9MxEDy
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# **Step 5: Run Streamlit with Ngrok**

# %%
from pyngrok import ngrok
ngrok.kill()

# !streamlit run app.py &>/content/logs.txt &
import time
time.sleep(5)

public_url = ngrok.connect(addr="8501", proto="http")
print(f"Public Streamlit URL: {public_url}")
# Out:
# Public Streamlit URL: NgrokTunnel: "https://7bd1ef17f430.ngrok-free.app" -> "http://localhost:8501"
